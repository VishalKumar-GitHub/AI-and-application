# %%
from IPython import display

# %%
display.Image("Submission form.jpg")

# %% [markdown]
# # (GH1021007) M504 AI AND APPLICATIONS FINAL ASSESSEMENT

# %% [markdown]
#                                                March 18, 2023

# %% [markdown]
# # 0.0.1 PYTHON ASSIGNMENT

# %% [markdown]
# ###### 0.0.2 As a data scientist, I have been approached by a startup that produces              shoes and they are seeking my advice on how to make their latest shoe              model a worldwide success. My task is to develop a plan to gather                        insights from various data sources, including sales data of other shoe                brands and their market structures.

# %% [markdown]
# ### 0.0.3 Importing  libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 0.0.4 visualization libraries

# %%
 import seaborn as sns
sns.set(color_codes = True)
import os
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
import sklearn.preprocessing

# %% [markdown]
# ### 0.0.5 Loading dataset

# %%
df = pd.read_csv("shoes data.csv")

# %%
df.head()
# Out:
#   Order Date      Brand                 Sneaker Name  Sale Price  \
# 0   9/7/2017  Off-White    Nike-Air-Max-90-Off-White        1600
# 1   9/7/2017  Off-White    Nike-Air-Max-90-Off-White        1090
# 2   9/7/2017  Off-White    Nike-Air-Presto-Off-White        1344
# 3   9/7/2017  Off-White    Nike-Air-Presto-Off-White        1325
# 4   9/7/2017  Off-White  Nike-Air-VaporMax-Off-White        1800
#
#    Retail Price Release Date  Shoe Size   Buyer Region
# 0           160     9/9/2017        8.0     California
# 1           160     9/9/2017       11.5       New York
# 2           160     9/9/2017       10.0       New York
# 3           160     9/9/2017       10.0  Massachusetts
# 4           250     9/9/2017       12.0       Kentucky

# %%
df.tail(15)
# Out:
#       Order Date      Brand                                    Sneaker Name  \
# 27779  2/13/2019  Off-White         Nike-Zoom-Fly-Mercurial-Off-White-Black
# 27780  2/13/2019  Off-White  Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange
# 27781  2/13/2019  Off-White  Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange
# 27782  2/13/2019  Off-White            Nike-Zoom-Fly-Off-White-Black-Silver
# 27783  2/13/2019  Off-White            Nike-Zoom-Fly-Off-White-Black-Silver
# 27784  2/13/2019  Off-White            Nike-Zoom-Fly-Off-White-Black-Silver
# 27785  2/13/2019  Off-White            Nike-Zoom-Fly-Off-White-Black-Silver
# 27786  2/13/2019  Off-White            Nike-Zoom-Fly-Off-White-Black-Silver
# 27787  2/13/2019  Off-White            Nike-Zoom-Fly-Off-White-Black-Silver
# 27788  2/13/2019  Off-White                    Nike-Zoom-Fly-Off-White-Pink
# 27789  2/13/2019  Off-White                    Nike-Zoom-Fly-Off-White-Pink
# ...

# %% [markdown]
# #### We have displayed the first and last few rows of the dataset.

# %%
df.dtypes
# Out:
# Order Date       object
# Brand            object
# Sneaker Name     object
# Sale Price        int64
# Retail Price      int64
# Release Date     object
# Shoe Size       float64
# Buyer Region     object
# dtype: object

# %% [markdown]
# #### We have verified the data type of the dataset.

# %% [markdown]
# ### 0.0.6 Checking for null values

# %%
 df.isnull().sum()
# Out:
# Order Date      0
# Brand           0
# Sneaker Name    0
# Sale Price      0
# Retail Price    0
# Release Date    0
# Shoe Size       0
# Buyer Region    0
# dtype: int64

# %% [markdown]
# #### Although there are no missing values in the dataset, we will still use the dropna() function to eliminate any columns that contain null values.

# %%
 df.dropna()
df.head()
# Out:
#   Order Date      Brand                 Sneaker Name  Sale Price  \
# 0   9/7/2017  Off-White    Nike-Air-Max-90-Off-White        1600
# 1   9/7/2017  Off-White    Nike-Air-Max-90-Off-White        1090
# 2   9/7/2017  Off-White    Nike-Air-Presto-Off-White        1344
# 3   9/7/2017  Off-White    Nike-Air-Presto-Off-White        1325
# 4   9/7/2017  Off-White  Nike-Air-VaporMax-Off-White        1800
#
#    Retail Price Release Date  Shoe Size   Buyer Region
# 0           160     9/9/2017        8.0     California
# 1           160     9/9/2017       11.5       New York
# 2           160     9/9/2017       10.0       New York
# 3           160     9/9/2017       10.0  Massachusetts
# 4           250     9/9/2017       12.0       Kentucky

# %% [markdown]
# #### Displaying the names of all the columns in the dataset.

# %%
 df.columns
# Out:
# Index(['Order Date', 'Brand', 'Sneaker Name', 'Sale Price', 'Retail Price',
#        'Release Date', 'Shoe Size', 'Buyer Region'],
#       dtype='object')

# %% [markdown]
# ### 0.0.7 Removing unnecessary columns from the dataset

# %%
df = df.drop("Brand",axis = 1)
df.head()
# Out:
#   Order Date                 Sneaker Name  Sale Price  Retail Price  \
# 0   9/7/2017    Nike-Air-Max-90-Off-White        1600           160
# 1   9/7/2017    Nike-Air-Max-90-Off-White        1090           160
# 2   9/7/2017    Nike-Air-Presto-Off-White        1344           160
# 3   9/7/2017    Nike-Air-Presto-Off-White        1325           160
# 4   9/7/2017  Nike-Air-VaporMax-Off-White        1800           250
#
#   Release Date  Shoe Size   Buyer Region
# 0     9/9/2017        8.0     California
# 1     9/9/2017       11.5       New York
# 2     9/9/2017       10.0       New York
# 3     9/9/2017       10.0  Massachusetts
# 4     9/9/2017       12.0       Kentucky

# %% [markdown]
# #### We have eliminated the brand information from the dataset as it is deemed irrelevant.

# %%
 df.describe()
# Out:
#          Sale Price  Retail Price     Shoe Size
# count  27794.000000  27794.000000  27794.000000
# mean     671.481291    179.378283      9.619001
# std      334.654935     33.066812      2.161367
# min      203.000000    130.000000      3.500000
# 25%      498.000000    160.000000      8.500000
# 50%      610.000000    170.000000     10.000000
# 75%      770.000000    190.000000     11.000000
# max     4050.000000    250.000000     17.000000

# %% [markdown]
# #### We have provided a summary of our dataset

# %% [markdown]
# ### 0.0.8 We are calculating the number of units sold for a particular shoe model.

# %%
df["Sneaker Name"].value_counts()
# Out:
# Air-Jordan-1-Retro-High-Off-White-University-Blue    4635
# Nike-Air-Presto-Off-White-Black-2018                 1884
# Nike-Air-Presto-Off-White-White-2018                 1883
# Nike-Air-VaporMax-Off-White-2018                     1591
# Nike-Blazer-Mid-Off-White-All-Hallows-Eve            1435
# Nike-Blazer-Mid-Off-White-Grim-Reaper                1398
# Nike-Zoom-Fly-Off-White-Pink                         1359
# Nike-Air-VaporMax-Off-White-Black                    1313
# Nike-Zoom-Fly-Off-White-Black-Silver                 1222
# Nike-Air-Force-1-Low-Off-White-Volt                  1019
# Nike-Air-Force-1-Low-Off-White-Black-White            960
# Air-Jordan-1-Retro-High-Off-White-Chicago             755
# Nike-Air-Max-90-Off-White-Black                       722
# Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange        656
# Nike-Air-Max-90-Off-White-Desert-Ore                  649
# Nike-Zoom-Fly-Mercurial-Off-White-Black               645
# ...

# %% [markdown]
# #### Air-Jordan-1-Retro-High-Off-White-University-Blue have the highest shoes sold.

# %% [markdown]
# ### 0.0.9 Checking which model have the highest sales price.

# %%
 df["Sneaker Name"][df["Sale Price"]== max(df["Sale Price"])]
# Out:
# 6000    Air-Jordan-1-Retro-High-Off-White-Chicago
# Name: Sneaker Name, dtype: object

# %% [markdown]
# ### 0.0.10  arranging dataset according to the release date to know how many models were released on a particular date.

# %%
 df.sort_values(by = "Release Date", ascending = True).head(10)
# Out:
#        Order Date                          Sneaker Name  Sale Price  \
# 21138  12/14/2018  Nike-Zoom-Fly-Off-White-Black-Silver         315
# 20597   12/8/2018  Nike-Zoom-Fly-Off-White-Black-Silver         364
# 20596   12/8/2018  Nike-Zoom-Fly-Off-White-Black-Silver         280
# 20595   12/8/2018  Nike-Zoom-Fly-Off-White-Black-Silver         330
# 20594   12/8/2018  Nike-Zoom-Fly-Off-White-Black-Silver         320
# 21304  12/15/2018  Nike-Zoom-Fly-Off-White-Black-Silver         265
# 21305  12/15/2018  Nike-Zoom-Fly-Off-White-Black-Silver         294
# 21306  12/15/2018  Nike-Zoom-Fly-Off-White-Black-Silver         304
# 21307  12/15/2018  Nike-Zoom-Fly-Off-White-Black-Silver         340
# 21308  12/15/2018  Nike-Zoom-Fly-Off-White-Black-Silver         315
#
#        Retail Price Release Date  Shoe Size Buyer Region
# 21138           170   10/13/2018       10.5   California
# 20597           170   10/13/2018       10.5  Connecticut
# ...

# %% [markdown]
# ### 0.0.11 We are identifying the geographic region that has the highest sales price.

# %%
 df["Buyer Region"][df["Sale Price"]== max(df["Sale Price"])]
# Out:
# 6000    Wisconsin
# Name: Buyer Region, dtype: object

# %% [markdown]
# #### Wisconsin have shoes with highest sales price.

# %% [markdown]
# ### 0.0.12 We are displaying a specific column, which is the sales price, to gain a deeper understanding of the data

# %%
 df["Sale Price"].head(10)
# Out:
# 0    1600
# 1    1090
# 2    1344
# 3    1325
# 4    1800
# 5    2450
# 6    2325
# 7     850
# 8    1299
# 9    2399
# Name: Sale Price, dtype: int64

# %% [markdown]
# ### 0.0.13 We are creating a bar chart to determine which shoe models had the highest sales.

# %%
 top_5 = df['Sneaker Name'].value_counts()[:5]
top_5.plot(kind='bar',figsize=(10,8))
plt.title('Top 5 models with starting price')
# Out:
# Text(0.5, 1.0, 'Top 5 models with starting price')

# %% [markdown]
# #### Air-Jordan-1-Retro-High-Off-White-University-Blue were sold highest.

# %% [markdown]
# ### 0.0.14 We are generating a bar graph to identify the geographic region with the highest shoe sales.

# %%
 top_5 = df['Buyer Region'].value_counts()[:5]
top_5.plot(kind='bar',figsize=(10,8))
plt.title('Top 5 regions with higher buying rate')
# Out:
# Text(0.5, 1.0, 'Top 5 regions with higher buying rate')

# %% [markdown]
# #### California has the highest buying rate.

# %% [markdown]
# ### 0.0.15 Creating a displot to determine which shoe size has the highest sales.

# %%
 x = df["Shoe Size"].values
sns.distplot(x, color = "Green")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### shoes size sale highest between 10 and 11.

# %% [markdown]
# ### 0.0.16 One way to determine the duration between the manufacturing and ordering of a shoe is by printing the                      release date and order date.

# %%
 df["Release Date"].head(10)
# Out:
# 0    9/9/2017
# 1    9/9/2017
# 2    9/9/2017
# 3    9/9/2017
# 4    9/9/2017
# 5    9/9/2017
# 6    9/9/2017
# 7    9/9/2017
# 8    9/9/2017
# 9    9/9/2017
# Name: Release Date, dtype: object

# %%
df["Order Date"].head(10)
# Out:
# 0    9/7/2017
# 1    9/7/2017
# 2    9/7/2017
# 3    9/7/2017
# 4    9/7/2017
# 5    9/8/2017
# 6    9/8/2017
# 7    9/8/2017
# 8    9/8/2017
# 9    9/8/2017
# Name: Order Date, dtype: object

# %% [markdown]
# ### 0.0.17 finding how many shoes were sold on a particular date here 9/7/2017.

# %%
 df[(["Sneaker Name"])
& (df["Order Date"] == "9/7/2017")]
# Out:
#   Order Date                 Sneaker Name  Sale Price  Retail Price  \
# 0   9/7/2017    Nike-Air-Max-90-Off-White        1600           160
# 1   9/7/2017    Nike-Air-Max-90-Off-White        1090           160
# 2   9/7/2017    Nike-Air-Presto-Off-White        1344           160
# 3   9/7/2017    Nike-Air-Presto-Off-White        1325           160
# 4   9/7/2017  Nike-Air-VaporMax-Off-White        1800           250
#
#   Release Date  Shoe Size   Buyer Region
# 0     9/9/2017        8.0     California
# 1     9/9/2017       11.5       New York
# 2     9/9/2017       10.0       New York
# 3     9/9/2017       10.0  Massachusetts
# 4     9/9/2017       12.0       Kentucky

# %% [markdown]
# ### 0.0.18 The instruction is to print or display shoes that have a retail price of 160.

# %%
 df[(["Sneaker Name"])
& (df["Retail Price"] == "160")]
# Out:
# Empty DataFrame
# Columns: [Order Date, Sneaker Name, Sale Price, Retail Price, Release Date, Shoe Size, Buyer Region]
# Index: []

# %% [raw]
# #### The shoes with a retail price of 250 had the highest sales numbers according to the sales data. The data also revealed that the majority of shoes were sold during September. Therefore, it is recommended that the client launches their new model in September with a retail price of at least 160, and they should prioritize releasing the model in California first. By following these guidelines, the model is predicted to be a global success.

# %% [markdown]
# ### 0.0.19 Reference

# %% [markdown]
# #### (1)

# %% [raw]
# shoes.csv. (n.d.). [Dataset; Managing environments]. In create anaconda environment (3.9). Available at: https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html

# %% [markdown]
# #### (2)

# %% [raw]
#        (2) Business insights for nike. (n.d.). [Dataset; Kaggle]. In Python · StockX Sneaker Data Contest (Version 2). Available at: https://www.kaggle.com/code/utribedi18/business-insights-for-nike/notebook
